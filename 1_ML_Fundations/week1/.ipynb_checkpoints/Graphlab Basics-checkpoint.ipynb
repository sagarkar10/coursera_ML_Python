# %%
import graphlab

# %%
sf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3d68b611cc5e> in <module>()
# ----> 1 sf
#
# NameError: name 'sf' is not defined

# %%
graphlab.numpy_loader
# Out:
# <module 'graphlab.numpy_loader' from '/home/sagarkar10/anaconda3/envs/dato-env/lib/python2.7/site-packages/graphlab/numpy_loader.pyc'>

# %%
graphlab.numpy_loader()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-db6a610d615f> in <module>()
# ----> 1 graphlab.numpy_loader()
#
# TypeError: 'module' object is not callable

# %%
numpy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-93d7964ec38e> in <module>()
# ----> 1 numpy
#
# NameError: name 'numpy' is not defined

# %%
a = [12,1,2,1,3,3,3,5,5,6,2,58,8,6]

# %%
a
# Out:
# [12, 1, 2, 1, 3, 3, 3, 5, 5, 6, 2, 58, 8, 6]

# %%
a.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-276f7237b96c> in <module>()
# ----> 1 a.show()
#
# AttributeError: 'list' object has no attribute 'show'

# %%
graphlab.show(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-890f3c72aafe> in <module>()
# ----> 1 graphlab.show(a)
#
# /home/sagarkar10/anaconda3/envs/dato-env/lib/python2.7/site-packages/graphlab/canvas/utils.pyc in show(variable)
#     123     """
#     124     if variable is not None:
# --> 125         get_target().state.set_selected_variable(variable)
#     126         variable.validate_js_component_name(variable.get_js_component())
#     127     return get_target().show()
#
# /home/sagarkar10/anaconda3/envs/dato-env/lib/python2.7/site-packages/graphlab/canvas/state.pyc in set_selected_variable(self, var)
#     122             if name is None:
#     123                 # if we can't find the name, add it as anonymous
# --> 124                 name = var.get_temporary_name()
#     125             # make sure this variable exists.
# ...

# %%
sf = graphlab.SFrame('FL_insurance_sample.csv')
# Out:
# [INFO] 1452260412 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to /home/sagarkar10/anaconda3/envs/dato-env/lib/python2.7/site-packages/certifi/cacert.pem
# 1452260412 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to sagarkar10@gmail.com and will expire on January 07, 2017. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-11677 - Server binary: /home/sagarkar10/anaconda3/envs/dato-env/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1452260412.log
# [INFO] GraphLab Server Version: 1.7.1
# PROGRESS: Finished parsing file /home/sagarkar10/anaconda3/envs/FL_insurance_sample.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.318239 secs.
# ...

# %%
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:43716/index.html
# Opening Canvas in default web browser.

# %%
sf.head()
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 10
#
# Data:
# +----------+-----------+-------------+---------------+---------------+---------------+
# | policyID | statecode |    county   | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-------------+---------------+---------------+---------------+
# |  119736  |     FL    | CLAY COUNTY |    498960.0   |    498960.0   |    498960.0   |
# |  448094  |     FL    | CLAY COUNTY |   1322376.3   |   1322376.3   |   1322376.3   |
# |  206893  |     FL    | CLAY COUNTY |    190724.4   |    190724.4   |    190724.4   |
# ...

# %%
dir(sf)
# Out:
# ['_SFrame__dropna_errchk',
#  '_SFrame__get_graphlabutil_reference_on_spark_unity_jar',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__get_column_description__',
#  '__get_pretty_tables__',
#  '__get_staging_dir__',
#  '__getattribute__',
#  '__getitem__',
#  '__has_size__',
#  '__hash__',
#  '__init__',
#  '__is_materialized__',
#  '__iter__',
#  '__len__',
#  '__materialize__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__proxy__',
#  '__query_plan_str__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__str_impl__',
#  '__subclasshook__',
#  '_cache',
#  '_group',
#  '_imagecols_to_stringcols',
#  '_infer_column_types_from_lines',
#  '_proxy',
#  '_read_csv_impl',
#  '_repr_html_',
#  '_row_selector',
#  '_save_reference',
#  'add_column',
#  'add_columns',
#  'add_row_number',
#  'append',
# ...

# %%
graphlab.canvas.set_target('ipynb')

# %%
sf.show()

# %%
'CLAY COUNTY' in sf['county']
# Out:
# True
